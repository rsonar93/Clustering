# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris_data = pd.read_csv("iris.csv")
iris_data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_data.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
iris_data.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_data.median()
# Out:
# Sepal.Length    5.80
# Sepal.Width     3.00
# Petal.Length    4.35
# Petal.Width     1.30
# dtype: float64

# %%
pd.notnull(iris_data)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0            True         True          True         True     True
# 1            True         True          True         True     True
# 2            True         True          True         True     True
# 3            True         True          True         True     True
# 4            True         True          True         True     True
# ..            ...          ...           ...          ...      ...
# 145          True         True          True         True     True
# 146          True         True          True         True     True
# 147          True         True          True         True     True
# 148          True         True          True         True     True
# 149          True         True          True         True     True
#
# [150 rows x 5 columns]

# %%
sns.lmplot(x='Sepal.Length',y='Sepal.Width',data=iris_data, hue='Species')

# %%
sns.pairplot(data=iris_data,hue='Species',palette='husl')

# %%
sns.jointplot(x='Sepal.Length',y='Sepal.Width',data=iris_data,color='maroon',kind='scatter',size=6)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\axisgrid.py:2272: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
a=sns.FacetGrid(data=iris_data,col='Species',hue='Species')
a.map(plt.scatter, 'Sepal.Length','Sepal.Width')

# %%
a=sns.FacetGrid(data=iris_data,col='Species',hue='Species')
a.map(plt.scatter, 'Petal.Length','Petal.Width')

# %%
sns.relplot(x='Petal.Length',y='Petal.Width',hue='Species',style='Species',data=iris_data)

# %%
sns.violinplot(x='Species',y='Petal.Width',data=iris_data)

# %%
#Types of Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
iris_new = iris_data[['Sepal.Length', 'Sepal.Width', 'Petal.Length','Petal.Width']]
iris_new
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
#iris2 = iris.drop(index=4)
#iris2

# %%
df = iris_data.iloc[:, 0:4]
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[149][0]
# Out:
# 5.9

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Loading the Libraries
from scipy.cluster.hierarchy import dendrogram, linkage

# Generate the linkage matrix
Z = linkage(df, method='ward', metric='euclidean', optimal_ordering=False)
fig = plt.figure(figsize =(25,10))
dn = dendrogram(Z,p=10)
plt.title('Hierarchial Clustering')
plt.xlabel('Species')
plt.ylabel('Distance')
# Out:
# Text(0, 0.5, 'Distance')
